# %% [markdown]
# # Load Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2

from keras.models import Model, Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
import os
import seaborn as sns

# %%
SIZE = 512
data_dir="../../data/large_files/multiclass/phishIRIS/"
out_dir=str(SIZE)+"/"
print(os.listdir(data_dir))
# Out:
# ['train', '.ipynb_checkpoints', 'val']

# %% [markdown]
# # Create test and train data arrays by iterating over the images in each folder

# %%
train_images = []
train_labels = [] 
for directory_path in glob.glob(data_dir+"train/*"):
    label = directory_path.split("/")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*.*")):
        print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)
        
train_images = np.array(train_images)
train_labels = np.array(train_labels)


# test
test_images = []
test_labels = [] 
for directory_path in glob.glob(data_dir+"val/*"):
    fruit_label = directory_path.split("/")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*.*")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)
        
test_images = np.array(test_images)
test_labels = np.array(test_labels)
# Out:
# apple
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (31).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (27).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (6).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (46).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (11).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (10).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (47).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (7).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (26).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (30).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (40).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (17).png
# ../../data/large_files/multiclass/phishIRIS/train/apple/apple (37).png
# ...

# %%
np.save(out_dir+"train_images", train_images)
np.save(out_dir+"test_images", test_images)
np.save(out_dir+"train_labels", train_labels)
np.save(out_dir+"test_labels", test_labels)

# %%
train_images.shape
# Out:
# (1313, 512, 512, 3)

# %%
test_images.shape
# Out:
# (1539, 512, 512, 3)
