# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! unzip 'gdrive/MyDrive/phishIRIS'
# Out:
# Archive:  gdrive/MyDrive/phishIRIS.zip
#    creating: phishIRIS/
#    creating: phishIRIS/train/
#    creating: phishIRIS/.ipynb_checkpoints/
#    creating: phishIRIS/val/
#    creating: phishIRIS/train/apple/
#    creating: phishIRIS/train/chase/
#    creating: phishIRIS/train/amazon/
#    creating: phishIRIS/train/microsoft/
#    creating: phishIRIS/train/other/
#    creating: phishIRIS/train/alibaba/
#    creating: phishIRIS/train/adobe/
#    creating: phishIRIS/train/facebook/
#    creating: phishIRIS/train/wellsfargo/
#    creating: phishIRIS/train/paypal/
#    creating: phishIRIS/train/boa/
#    creating: phishIRIS/train/dropbox/
#    creating: phishIRIS/train/dhl/
#    creating: phishIRIS/train/linkedin/
#    creating: phishIRIS/train/yahoo/
#    creating: phishIRIS/val/apple/
#    creating: phishIRIS/val/chase/
#    creating: phishIRIS/val/amazon/
#    creating: phishIRIS/val/microsoft/
#    creating: phishIRIS/val/other/
#    creating: phishIRIS/val/alibaba/
#    creating: phishIRIS/val/adobe/
#    creating: phishIRIS/val/facebook/
#    creating: phishIRIS/val/wellsfargo/
#    creating: phishIRIS/val/paypal/
#    creating: phishIRIS/val/boa/
#    creating: phishIRIS/val/dropbox/
#    creating: phishIRIS/val/dhl/
#    creating: phishIRIS/val/linkedin/
#    creating: phishIRIS/val/yahoo/
#   inflating: phishIRIS/train/apple/apple (31).png
#   inflating: phishIRIS/train/apple/apple (27).png
#   inflating: phishIRIS/train/apple/apple (6).png
#   inflating: phishIRIS/train/apple/apple (46).png
#   inflating: phishIRIS/train/apple/apple (11).png
#   inflating: phishIRIS/train/apple/apple (10).png
#   inflating: phishIRIS/train/apple/apple (47).png
#   inflating: phishIRIS/train/apple/apple (7).png
#   inflating: phishIRIS/train/apple/apple (26).png
#   inflating: phishIRIS/train/apple/apple (30).png
#   inflating: phishIRIS/train/apple/apple (40).png
#   inflating: phishIRIS/train/apple/apple (17).png
#   inflating: phishIRIS/train/apple/apple (37).png
#   inflating: phishIRIS/train/apple/apple (21).png
#   inflating: phishIRIS/train/apple/apple (1).png
#   inflating: phishIRIS/train/apple/apple (20).png
#   inflating: phishIRIS/train/apple/apple (36).png
#   inflating: phishIRIS/train/apple/apple (16).png
#   inflating: phishIRIS/train/apple/apple (41).png
#   inflating: phishIRIS/train/apple/apple (39).png
#   inflating: phishIRIS/train/apple/apple (15).png
#   inflating: phishIRIS/train/apple/apple (42).png
#   inflating: phishIRIS/train/apple/apple (2).png
#   inflating: phishIRIS/train/apple/apple (23).png
#   inflating: phishIRIS/train/apple/apple (35).png
#   inflating: phishIRIS/train/apple/apple (19).png
#   inflating: phishIRIS/train/apple/apple (18).png
#   inflating: phishIRIS/train/apple/apple (34).png
#   inflating: phishIRIS/train/apple/apple (22).png
#   inflating: phishIRIS/train/apple/apple (3).png
#   inflating: phishIRIS/train/apple/apple (43).png
#   inflating: phishIRIS/train/apple/apple (14).png
#   inflating: phishIRIS/train/apple/apple (38).png
#   inflating: phishIRIS/train/apple/apple (4).png
#   inflating: phishIRIS/train/apple/apple (25).png
#   inflating: phishIRIS/train/apple/apple (33).png
#   inflating: phishIRIS/train/apple/apple (48).png
#   inflating: phishIRIS/train/apple/apple (8).png
#   inflating: phishIRIS/train/apple/apple (29).png
#   inflating: phishIRIS/train/apple/apple (13).png
#   inflating: phishIRIS/train/apple/apple (44).png
#   inflating: phishIRIS/train/apple/apple (45).png
#   inflating: phishIRIS/train/apple/apple (12).png
#   inflating: phishIRIS/train/apple/apple (28).png
#   inflating: phishIRIS/train/apple/apple (9).png
#   inflating: phishIRIS/train/apple/apple (49).png
#   inflating: phishIRIS/train/apple/apple (32).png
#   inflating: phishIRIS/train/apple/apple (24).png
#   inflating: phishIRIS/train/apple/apple (5).png
#   inflating: phishIRIS/train/chase/chase (26).png
#   inflating: phishIRIS/train/chase/chase (30).png
#   inflating: phishIRIS/train/chase/chase (2).jpg
#   inflating: phishIRIS/train/chase/chase (10).png
#   inflating: phishIRIS/train/chase/chase (10).jpg
#   inflating: phishIRIS/train/chase/chase (2).png
#   inflating: phishIRIS/train/chase/chase (47).png
#   inflating: phishIRIS/train/chase/chase (51).png
#   inflating: phishIRIS/train/chase/chase (50).png
#   inflating: phishIRIS/train/chase/chase (46).png
#   inflating: phishIRIS/train/chase/chase (11).jpg
#   inflating: phishIRIS/train/chase/chase (3).png
#   inflating: phishIRIS/train/chase/chase (3).jpg
#   inflating: phishIRIS/train/chase/chase (11).png
#   inflating: phishIRIS/train/chase/chase (31).png
#   inflating: phishIRIS/train/chase/chase (27).png
#   inflating: phishIRIS/train/chase/chase (16).png
#   inflating: phishIRIS/train/chase/chase (4).jpg
#   inflating: phishIRIS/train/chase/chase (4).png
#   inflating: phishIRIS/train/chase/chase (16).jpg
#   inflating: phishIRIS/train/chase/chase (41).png
#   inflating: phishIRIS/train/chase/chase (8).jpg
#   inflating: phishIRIS/train/chase/chase (8).png
#   inflating: phishIRIS/train/chase/chase (20).jpg
#   inflating: phishIRIS/train/chase/chase (20).png
#   inflating: phishIRIS/train/chase/chase (36).png
#   inflating: phishIRIS/train/chase/chase (37).png
#   inflating: phishIRIS/train/chase/chase (21).png
#   inflating: phishIRIS/train/chase/chase (21).jpg
#   inflating: phishIRIS/train/chase/chase (9).png
#   inflating: phishIRIS/train/chase/chase (9).jpg
#   inflating: phishIRIS/train/chase/chase (40).png
#   inflating: phishIRIS/train/chase/chase (5).png
#   inflating: phishIRIS/train/chase/chase (17).jpg
#   inflating: phishIRIS/train/chase/chase (17).png
#   inflating: phishIRIS/train/chase/chase (5).jpg
#   inflating: phishIRIS/train/chase/chase (38).png
#   inflating: phishIRIS/train/chase/chase (43).png
#   inflating: phishIRIS/train/chase/chase (14).jpg
#   inflating: phishIRIS/train/chase/chase (6).png
#   inflating: phishIRIS/train/chase/chase (6).jpg
#   inflating: phishIRIS/train/chase/chase (14).png
#   inflating: phishIRIS/train/chase/chase (34).png
#   inflating: phishIRIS/train/chase/chase (22).png
#   inflating: phishIRIS/train/chase/chase (22).jpg
#   inflating: phishIRIS/train/chase/chase (18).jpg
#   inflating: phishIRIS/train/chase/chase (18).png
#   inflating: phishIRIS/train/chase/chase (19).png
#   inflating: phishIRIS/train/chase/chase (19).jpg
#   inflating: phishIRIS/train/chase/chase (23).png
#   inflating: phishIRIS/train/chase/chase (35).png
#   inflating: phishIRIS/train/chase/chase (7).jpg
#   inflating: phishIRIS/train/chase/chase (15).png
#   inflating: phishIRIS/train/chase/chase (15).jpg
#   inflating: phishIRIS/train/chase/chase (7).png
#   inflating: phishIRIS/train/chase/chase (42).png
#   inflating: phishIRIS/train/chase/chase (39).png
#   inflating: phishIRIS/train/chase/chase (32).png
#   inflating: phishIRIS/train/chase/chase (24).png
#   inflating: phishIRIS/train/chase/chase (49).png
#   inflating: phishIRIS/train/chase/chase (28).png
#   inflating: phishIRIS/train/chase/chase (45).png
#   inflating: phishIRIS/train/chase/chase (12).jpg
#   inflating: phishIRIS/train/chase/chase (12).png
#   inflating: phishIRIS/train/chase/chase (13).png
#   inflating: phishIRIS/train/chase/chase (1).jpg
#   inflating: phishIRIS/train/chase/chase (1).png
#   inflating: phishIRIS/train/chase/chase (13).jpg
#   inflating: phishIRIS/train/chase/chase (44).png
#   inflating: phishIRIS/train/chase/chase (52).png
#   inflating: phishIRIS/train/chase/chase (29).png
#   inflating: phishIRIS/train/chase/chase (48).png
#   inflating: phishIRIS/train/chase/chase (25).png
#   inflating: phishIRIS/train/chase/chase (33).png
#   inflating: phishIRIS/train/amazon/amazon (7).png
#   inflating: phishIRIS/train/amazon/amazon (16).png
#   inflating: phishIRIS/train/amazon/amazon (17).png
#   inflating: phishIRIS/train/amazon/amazon (6).png
#   inflating: phishIRIS/train/amazon/amazon (10).png
#   inflating: phishIRIS/train/amazon/amazon (1).png
#   inflating: phishIRIS/train/amazon/amazon (11).png
#   inflating: phishIRIS/train/amazon/amazon (12).png
#   inflating: phishIRIS/train/amazon/amazon (3).png
#   inflating: phishIRIS/train/amazon/amazon (2).png
#   inflating: phishIRIS/train/amazon/amazon (13).png
#   inflating: phishIRIS/train/amazon/amazon (18).png
#   inflating: phishIRIS/train/amazon/amazon (5).png
#   inflating: phishIRIS/train/amazon/amazon (9).png
#   inflating: phishIRIS/train/amazon/amazon (14).png
#   inflating: phishIRIS/train/amazon/amazon (8).png
#   inflating: phishIRIS/train/amazon/amazon (15).png
#   inflating: phishIRIS/train/amazon/amazon (4).png
#   inflating: phishIRIS/train/microsoft/microsoft (10).png
#   inflating: phishIRIS/train/microsoft/microsoft (47).png
#   inflating: phishIRIS/train/microsoft/microsoft (51).png
#   inflating: phishIRIS/train/microsoft/microsoft (26).png
#   inflating: phishIRIS/train/microsoft/microsoft (30).png
#   inflating: phishIRIS/train/microsoft/microsoft (1).jpg
#   inflating: phishIRIS/train/microsoft/microsoft (1).png
#   inflating: phishIRIS/train/microsoft/microsoft (31).png
#   inflating: phishIRIS/train/microsoft/microsoft (27).png
#   inflating: phishIRIS/train/microsoft/microsoft (50).png
#   inflating: phishIRIS/train/microsoft/microsoft (46).png
#   inflating: phishIRIS/train/microsoft/microsoft (11).png
#   inflating: phishIRIS/train/microsoft/microsoft (20).png
#   inflating: phishIRIS/train/microsoft/microsoft (36).png
#   inflating: phishIRIS/train/microsoft/microsoft (61).png
#   inflating: phishIRIS/train/microsoft/microsoft (7).png
#   inflating: phishIRIS/train/microsoft/microsoft (16).png
#   inflating: phishIRIS/train/microsoft/microsoft (41).png
#   inflating: phishIRIS/train/microsoft/microsoft (57).png
#   inflating: phishIRIS/train/microsoft/microsoft (56).png
#   inflating: phishIRIS/train/microsoft/microsoft (40).png
#   inflating: phishIRIS/train/microsoft/microsoft (17).png
#   inflating: phishIRIS/train/microsoft/microsoft (6).png
#   inflating: phishIRIS/train/microsoft/microsoft (60).png
#   inflating: phishIRIS/train/microsoft/microsoft (37).png
#   inflating: phishIRIS/train/microsoft/microsoft (21).png
#   inflating: phishIRIS/train/microsoft/microsoft (59).png
#   inflating: phishIRIS/train/microsoft/microsoft (5).png
#   inflating: phishIRIS/train/microsoft/microsoft (18).png
#   inflating: phishIRIS/train/microsoft/microsoft (63).png
#   inflating: phishIRIS/train/microsoft/microsoft (34).png
#   inflating: phishIRIS/train/microsoft/microsoft (22).png
#   inflating: phishIRIS/train/microsoft/microsoft (55).png
#   inflating: phishIRIS/train/microsoft/microsoft (43).png
#   inflating: phishIRIS/train/microsoft/microsoft (9).png
#   inflating: phishIRIS/train/microsoft/microsoft (14).png
#   inflating: phishIRIS/train/microsoft/microsoft (38).png
#   inflating: phishIRIS/train/microsoft/microsoft (39).png
#   inflating: phishIRIS/train/microsoft/microsoft (15).png
#   inflating: phishIRIS/train/microsoft/microsoft (8).png
#   inflating: phishIRIS/train/microsoft/microsoft (42).png
#   inflating: phishIRIS/train/microsoft/microsoft (54).png
#   inflating: phishIRIS/train/microsoft/microsoft (23).png
#   inflating: phishIRIS/train/microsoft/microsoft (35).png
#   inflating: phishIRIS/train/microsoft/microsoft (62).png
#   inflating: phishIRIS/train/microsoft/microsoft (19).png
#   inflating: phishIRIS/train/microsoft/microsoft (4).png
#   inflating: phishIRIS/train/microsoft/microsoft (58).png
#   inflating: phishIRIS/train/microsoft/microsoft (53).png
#   inflating: phishIRIS/train/microsoft/microsoft (45).png
#   inflating: phishIRIS/train/microsoft/microsoft (12).png
#   inflating: phishIRIS/train/microsoft/microsoft (28).png
#   inflating: phishIRIS/train/microsoft/microsoft (3).png
#   inflating: phishIRIS/train/microsoft/microsoft (49).png
#   inflating: phishIRIS/train/microsoft/microsoft (32).png
#   inflating: phishIRIS/train/microsoft/microsoft (24).png
#   inflating: phishIRIS/train/microsoft/microsoft (25).png
#   inflating: phishIRIS/train/microsoft/microsoft (33).png
#   inflating: phishIRIS/train/microsoft/microsoft (2).jpg
#   inflating: phishIRIS/train/microsoft/microsoft (48).png
#   inflating: phishIRIS/train/microsoft/microsoft (2).png
#   inflating: phishIRIS/train/microsoft/microsoft (29).png
#   inflating: phishIRIS/train/microsoft/microsoft (13).png
#   inflating: phishIRIS/train/microsoft/microsoft (44).png
#   inflating: phishIRIS/train/microsoft/microsoft (52).png
#   inflating: phishIRIS/train/other/other (167).png
#   inflating: phishIRIS/train/other/other (3).png
#   inflating: phishIRIS/train/other/other (25).jpg
#   inflating: phishIRIS/train/other/other (188).png
#   inflating: phishIRIS/train/other/other (130).jpg
#   inflating: phishIRIS/train/other/other (72).png
#   inflating: phishIRIS/train/other/other (130).png
#   inflating: phishIRIS/train/other/other (72).jpg
#   inflating: phishIRIS/train/other/other (3).jpg
#   inflating: phishIRIS/train/other/other (167).jpg
#   inflating: phishIRIS/train/other/other (25).png
#   inflating: phishIRIS/train/other/other (126).png
#   inflating: phishIRIS/train/other/other (64).jpg
#   inflating: phishIRIS/train/other/other (171).jpg
#   inflating: phishIRIS/train/other/other (33).png
#   inflating: phishIRIS/train/other/other (171).png
#   inflating: phishIRIS/train/other/other (33).jpg
#   inflating: phishIRIS/train/other/other (126).jpg
#   inflating: phishIRIS/train/other/other (64).png
#   inflating: phishIRIS/train/other/other (48).jpg
#   inflating: phishIRIS/train/other/other (48).png
#   inflating: phishIRIS/train/other/other (91).png
#   inflating: phishIRIS/train/other/other (184).png
#   inflating: phishIRIS/train/other/other (29).jpg
#   inflating: phishIRIS/train/other/other (29).png
#   inflating: phishIRIS/train/other/other (184).jpg
#   inflating: phishIRIS/train/other/other (91).jpg
#   inflating: phishIRIS/train/other/other (203).png
#   inflating: phishIRIS/train/other/other (87).jpg
#   inflating: phishIRIS/train/other/other (68).jpg
#   inflating: phishIRIS/train/other/other (87).png
#   inflating: phishIRIS/train/other/other (68).png
#   inflating: phishIRIS/train/other/other (192).png
#   inflating: phishIRIS/train/other/other (13).png
#   inflating: phishIRIS/train/other/other (151).jpg
#   inflating: phishIRIS/train/other/other (44).jpg
#   inflating: phishIRIS/train/other/other (106).png
#   inflating: phishIRIS/train/other/other (44).png
#   inflating: phishIRIS/train/other/other (106).jpg
#   inflating: phishIRIS/train/other/other (13).jpg
#   inflating: phishIRIS/train/other/other (151).png
#   inflating: phishIRIS/train/other/other (52).png
#   inflating: phishIRIS/train/other/other (110).jpg
#   inflating: phishIRIS/train/other/other (147).png
#   inflating: phishIRIS/train/other/other (147).jpg
#   inflating: phishIRIS/train/other/other (52).jpg
#   inflating: phishIRIS/train/other/other (110).png
#   inflating: phishIRIS/train/other/other (53).jpg
#   inflating: phishIRIS/train/other/other (111).png
#   inflating: phishIRIS/train/other/other (146).jpg
#   inflating: phishIRIS/train/other/other (146).png
#   inflating: phishIRIS/train/other/other (53).png
#   inflating: phishIRIS/train/other/other (111).jpg
#   inflating: phishIRIS/train/other/other (12).jpg
#   inflating: phishIRIS/train/other/other (150).png
#   inflating: phishIRIS/train/other/other (45).png
#   inflating: phishIRIS/train/other/other (107).jpg
#   inflating: phishIRIS/train/other/other (45).jpg
#   inflating: phishIRIS/train/other/other (107).png
#   inflating: phishIRIS/train/other/other (12).png
#   inflating: phishIRIS/train/other/other (150).jpg
#   inflating: phishIRIS/train/other/other (193).png
#   inflating: phishIRIS/train/other/other (86).png
#   inflating: phishIRIS/train/other/other (69).png
#   inflating: phishIRIS/train/other/other (86).jpg
#   inflating: phishIRIS/train/other/other (69).jpg
#   inflating: phishIRIS/train/other/other (202).png
#   inflating: phishIRIS/train/other/other (90).jpg
#   inflating: phishIRIS/train/other/other (28).png
#   inflating: phishIRIS/train/other/other (214).png
#   inflating: phishIRIS/train/other/other (185).jpg
#   inflating: phishIRIS/train/other/other (185).png
#   inflating: phishIRIS/train/other/other (28).jpg
#   inflating: phishIRIS/train/other/other (90).png
#   inflating: phishIRIS/train/other/other (49).png
#   inflating: phishIRIS/train/other/other (49).jpg
#   inflating: phishIRIS/train/other/other (127).jpg
#   inflating: phishIRIS/train/other/other (65).png
#   inflating: phishIRIS/train/other/other (170).png
#   inflating: phishIRIS/train/other/other (32).jpg
#   inflating: phishIRIS/train/other/other (170).jpg
#   inflating: phishIRIS/train/other/other (32).png
#   inflating: phishIRIS/train/other/other (127).png
#   inflating: phishIRIS/train/other/other (65).jpg
#   inflating: phishIRIS/train/other/other (2).jpg
#   inflating: phishIRIS/train/other/other (166).jpg
#   inflating: phishIRIS/train/other/other (24).png
#   inflating: phishIRIS/train/other/other (131).png
#   inflating: phishIRIS/train/other/other (73).jpg
#   inflating: phishIRIS/train/other/other (131).jpg
#   inflating: phishIRIS/train/other/other (73).png
#   inflating: phishIRIS/train/other/other (166).png
#   inflating: phishIRIS/train/other/other (2).png
#   inflating: phishIRIS/train/other/other (24).jpg
#   inflating: phishIRIS/train/other/other (189).png
#   inflating: phishIRIS/train/other/other (97).png
#   inflating: phishIRIS/train/other/other (78).png
#   inflating: phishIRIS/train/other/other (9).png
#   inflating: phishIRIS/train/other/other (182).png
#   inflating: phishIRIS/train/other/other (9).jpg
#   inflating: phishIRIS/train/other/other (182).jpg
#   inflating: phishIRIS/train/other/other (213).png
#   inflating: phishIRIS/train/other/other (97).jpg
#   inflating: phishIRIS/train/other/other (78).jpg
#   inflating: phishIRIS/train/other/other (205).png
#   inflating: phishIRIS/train/other/other (39).png
#   inflating: phishIRIS/train/other/other (81).jpg
#   inflating: phishIRIS/train/other/other (81).png
#   inflating: phishIRIS/train/other/other (194).png
#   inflating: phishIRIS/train/other/other (39).jpg
#   inflating: phishIRIS/train/other/other (15).png
#   inflating: phishIRIS/train/other/other (157).jpg
#   inflating: phishIRIS/train/other/other (42).jpg
#   inflating: phishIRIS/train/other/other (100).png
#   inflating: phishIRIS/train/other/other (42).png
#   inflating: phishIRIS/train/other/other (100).jpg
#   inflating: phishIRIS/train/other/other (15).jpg
#   inflating: phishIRIS/train/other/other (157).png
#   inflating: phishIRIS/train/other/other (54).png
#   inflating: phishIRIS/train/other/other (116).jpg
#   inflating: phishIRIS/train/other/other (141).png
#   inflating: phishIRIS/train/other/other (141).jpg
#   inflating: phishIRIS/train/other/other (54).jpg
#   inflating: phishIRIS/train/other/other (116).png
#   inflating: phishIRIS/train/other/other (5).png
#   inflating: phishIRIS/train/other/other (161).png
#   inflating: phishIRIS/train/other/other (23).jpg
#   inflating: phishIRIS/train/other/other (136).jpg
#   inflating: phishIRIS/train/other/other (74).png
#   inflating: phishIRIS/train/other/other (136).png
#   inflating: phishIRIS/train/other/other (74).jpg
#   inflating: phishIRIS/train/other/other (161).jpg
#   inflating: phishIRIS/train/other/other (5).jpg
#   inflating: phishIRIS/train/other/other (23).png
#   inflating: phishIRIS/train/other/other (120).png
#   inflating: phishIRIS/train/other/other (62).jpg
#   inflating: phishIRIS/train/other/other (177).jpg
#   inflating: phishIRIS/train/other/other (35).png
#   inflating: phishIRIS/train/other/other (209).png
#   inflating: phishIRIS/train/other/other (177).png
#   inflating: phishIRIS/train/other/other (35).jpg
#   inflating: phishIRIS/train/other/other (198).png
#   inflating: phishIRIS/train/other/other (120).jpg
#   inflating: phishIRIS/train/other/other (62).png
#   inflating: phishIRIS/train/other/other (19).png
#   inflating: phishIRIS/train/other/other (19).jpg
#   inflating: phishIRIS/train/other/other (58).png
#   inflating: phishIRIS/train/other/other (58).jpg
#   inflating: phishIRIS/train/other/other (59).jpg
#   inflating: phishIRIS/train/other/other (59).png
#   inflating: phishIRIS/train/other/other (18).jpg
#   inflating: phishIRIS/train/other/other (18).png
#   inflating: phishIRIS/train/other/other (121).jpg
#   inflating: phishIRIS/train/other/other (63).png
#   inflating: phishIRIS/train/other/other (176).png
#   inflating: phishIRIS/train/other/other (34).jpg
#   inflating: phishIRIS/train/other/other (199).png
#   inflating: phishIRIS/train/other/other (176).jpg
#   inflating: phishIRIS/train/other/other (208).png
#   inflating: phishIRIS/train/other/other (34).png
#   inflating: phishIRIS/train/other/other (121).png
#   inflating: phishIRIS/train/other/other (63).jpg
#   inflating: phishIRIS/train/other/other (160).jpg
#   inflating: phishIRIS/train/other/other (4).jpg
#   inflating: phishIRIS/train/other/other (22).png
#   inflating: phishIRIS/train/other/other (137).png
#   inflating: phishIRIS/train/other/other (75).jpg
#   inflating: phishIRIS/train/other/other (137).jpg
#   inflating: phishIRIS/train/other/other (75).png
#   inflating: phishIRIS/train/other/other (4).png
#   inflating: phishIRIS/train/other/other (160).png
#   inflating: phishIRIS/train/other/other (22).jpg
#   inflating: phishIRIS/train/other/other (55).jpg
#   inflating: phishIRIS/train/other/other (117).png
#   inflating: phishIRIS/train/other/other (140).jpg
#   inflating: phishIRIS/train/other/other (140).png
#   inflating: phishIRIS/train/other/other (55).png
#   inflating: phishIRIS/train/other/other (117).jpg
#   inflating: phishIRIS/train/other/other (14).jpg
#   inflating: phishIRIS/train/other/other (156).png
#   inflating: phishIRIS/train/other/other (43).png
#   inflating: phishIRIS/train/other/other (101).jpg
#   inflating: phishIRIS/train/other/other (43).jpg
#   inflating: phishIRIS/train/other/other (101).png
#   inflating: phishIRIS/train/other/other (14).png
#   inflating: phishIRIS/train/other/other (156).jpg
#   inflating: phishIRIS/train/other/other (195).png
#   inflating: phishIRIS/train/other/other (38).jpg
#   inflating: phishIRIS/train/other/other (80).png
#   inflating: phishIRIS/train/other/other (80).jpg
#   inflating: phishIRIS/train/other/other (38).png
#   inflating: phishIRIS/train/other/other (204).png
#   inflating: phishIRIS/train/other/other (96).jpg
#   inflating: phishIRIS/train/other/other (79).jpg
#   inflating: phishIRIS/train/other/other (8).jpg
#   inflating: phishIRIS/train/other/other (183).jpg
#   inflating: phishIRIS/train/other/other (212).png
#   inflating: phishIRIS/train/other/other (8).png
#   inflating: phishIRIS/train/other/other (183).png
#   inflating: phishIRIS/train/other/other (96).png
#   inflating: phishIRIS/train/other/other (79).png
#   inflating: phishIRIS/train/other/other (114).png
#   inflating: phishIRIS/train/other/other (56).jpg
#   inflating: phishIRIS/train/other/other (143).jpg
#   inflating: phishIRIS/train/other/other (143).png
#   inflating: phishIRIS/train/other/other (114).jpg
#   inflating: phishIRIS/train/other/other (56).png
#   inflating: phishIRIS/train/other/other (155).png
#   inflating: phishIRIS/train/other/other (17).jpg
#   inflating: phishIRIS/train/other/other (102).jpg
#   inflating: phishIRIS/train/other/other (40).png
#   inflating: phishIRIS/train/other/other (102).png
#   inflating: phishIRIS/train/other/other (40).jpg
#   inflating: phishIRIS/train/other/other (155).jpg
#   inflating: phishIRIS/train/other/other (17).png
#   inflating: phishIRIS/train/other/other (196).png
#   inflating: phishIRIS/train/other/other (179).png
#   inflating: phishIRIS/train/other/other (83).png
#   inflating: phishIRIS/train/other/other (83).jpg
#   inflating: phishIRIS/train/other/other (207).png
#   inflating: phishIRIS/train/other/other (179).jpg
#   inflating: phishIRIS/train/other/other (138).png
#   inflating: phishIRIS/train/other/other (95).jpg
#   inflating: phishIRIS/train/other/other (211).png
#   inflating: phishIRIS/train/other/other (180).jpg
#   inflating: phishIRIS/train/other/other (180).png
#   inflating: phishIRIS/train/other/other (95).png
#   inflating: phishIRIS/train/other/other (138).jpg
#   inflating: phishIRIS/train/other/other (118).png
#   inflating: phishIRIS/train/other/other (118).jpg
#   inflating: phishIRIS/train/other/other (159).png
#   inflating: phishIRIS/train/other/other (159).jpg
#   inflating: phishIRIS/train/other/other (60).png
#   inflating: phishIRIS/train/other/other (122).jpg
#   inflating: phishIRIS/train/other/other (37).jpg
#   inflating: phishIRIS/train/other/other (175).png
#   inflating: phishIRIS/train/other/other (37).png
#   inflating: phishIRIS/train/other/other (175).jpg
#   inflating: phishIRIS/train/other/other (60).jpg
#   inflating: phishIRIS/train/other/other (122).png
#   inflating: phishIRIS/train/other/other (21).png
#   inflating: phishIRIS/train/other/other (7).jpg
#   inflating: phishIRIS/train/other/other (163).jpg
#   inflating: phishIRIS/train/other/other (76).jpg
#   inflating: phishIRIS/train/other/other (99).jpg
#   inflating: phishIRIS/train/other/other (134).png
#   inflating: phishIRIS/train/other/other (76).png
#   inflating: phishIRIS/train/other/other (134).jpg
#   inflating: phishIRIS/train/other/other (99).png
#   inflating: phishIRIS/train/other/other (21).jpg
#   inflating: phishIRIS/train/other/other (163).png
#   inflating: phishIRIS/train/other/other (7).png
#   inflating: phishIRIS/train/other/other (20).jpg
#   inflating: phishIRIS/train/other/other (162).png
#   inflating: phishIRIS/train/other/other (6).png
#   inflating: phishIRIS/train/other/other (77).png
#   inflating: phishIRIS/train/other/other (135).jpg
#   inflating: phishIRIS/train/other/other (98).png
#   inflating: phishIRIS/train/other/other (77).jpg
#   inflating: phishIRIS/train/other/other (98).jpg
#   inflating: phishIRIS/train/other/other (135).png
#   inflating: phishIRIS/train/other/other (20).png
#   inflating: phishIRIS/train/other/other (6).jpg
#   inflating: phishIRIS/train/other/other (162).jpg
#   inflating: phishIRIS/train/other/other (61).jpg
#   inflating: phishIRIS/train/other/other (123).png
#   inflating: phishIRIS/train/other/other (36).png
#   inflating: phishIRIS/train/other/other (174).jpg
#   inflating: phishIRIS/train/other/other (36).jpg
#   inflating: phishIRIS/train/other/other (174).png
#   inflating: phishIRIS/train/other/other (61).png
#   inflating: phishIRIS/train/other/other (123).jpg
#   inflating: phishIRIS/train/other/other (158).jpg
#   inflating: phishIRIS/train/other/other (158).png
#   inflating: phishIRIS/train/other/other (119).jpg
#   inflating: phishIRIS/train/other/other (119).png
#   inflating: phishIRIS/train/other/other (94).png
#   inflating: phishIRIS/train/other/other (139).jpg
#   inflating: phishIRIS/train/other/other (181).png
#   inflating: phishIRIS/train/other/other (210).png
#   inflating: phishIRIS/train/other/other (181).jpg
#   inflating: phishIRIS/train/other/other (139).png
#   inflating: phishIRIS/train/other/other (94).jpg
#   inflating: phishIRIS/train/other/other (206).png
#   inflating: phishIRIS/train/other/other (178).jpg
#   inflating: phishIRIS/train/other/other (82).jpg
#   inflating: phishIRIS/train/other/other (82).png
#   inflating: phishIRIS/train/other/other (197).png
#   inflating: phishIRIS/train/other/other (178).png
#   inflating: phishIRIS/train/other/other (154).jpg
#   inflating: phishIRIS/train/other/other (16).png
#   inflating: phishIRIS/train/other/other (103).png
#   inflating: phishIRIS/train/other/other (41).jpg
#   inflating: phishIRIS/train/other/other (103).jpg
#   inflating: phishIRIS/train/other/other (41).png
#   inflating: phishIRIS/train/other/other (154).png
#   inflating: phishIRIS/train/other/other (16).jpg
#   inflating: phishIRIS/train/other/other (115).jpg
#   inflating: phishIRIS/train/other/other (57).png
#   inflating: phishIRIS/train/other/other (142).png
#   inflating: phishIRIS/train/other/other (142).jpg
#   inflating: phishIRIS/train/other/other (115).png
#   inflating: phishIRIS/train/other/other (57).jpg
#   inflating: phishIRIS/train/other/other (149).jpg
#   inflating: phishIRIS/train/other/other (149).png
#   inflating: phishIRIS/train/other/other (108).jpg
#   inflating: phishIRIS/train/other/other (108).png
#   inflating: phishIRIS/train/other/other (66).png
#   inflating: phishIRIS/train/other/other (124).jpg
#   inflating: phishIRIS/train/other/other (89).png
#   inflating: phishIRIS/train/other/other (31).jpg
#   inflating: phishIRIS/train/other/other (173).png
#   inflating: phishIRIS/train/other/other (31).png
#   inflating: phishIRIS/train/other/other (173).jpg
#   inflating: phishIRIS/train/other/other (66).jpg
#   inflating: phishIRIS/train/other/other (89).jpg
#   inflating: phishIRIS/train/other/other (124).png
#   inflating: phishIRIS/train/other/other (27).png
#   inflating: phishIRIS/train/other/other (165).jpg
#   inflating: phishIRIS/train/other/other (1).jpg
#   inflating: phishIRIS/train/other/other (70).jpg
#   inflating: phishIRIS/train/other/other (132).png
#   inflating: phishIRIS/train/other/other (70).png
#   inflating: phishIRIS/train/other/other (132).jpg
#   inflating: phishIRIS/train/other/other (27).jpg
#   inflating: phishIRIS/train/other/other (1).png
#   inflating: phishIRIS/train/other/other (165).png
#   inflating: phishIRIS/train/other/other (112).png
#   inflating: phishIRIS/train/other/other (50).jpg
#   inflating: phishIRIS/train/other/other (145).jpg
#   inflating: phishIRIS/train/other/other (145).png
#   inflating: phishIRIS/train/other/other (112).jpg
#   inflating: phishIRIS/train/other/other (50).png
#   inflating: phishIRIS/train/other/other (153).png
#   inflating: phishIRIS/train/other/other (11).jpg
#   inflating: phishIRIS/train/other/other (104).jpg
#   inflating: phishIRIS/train/other/other (46).png
#   inflating: phishIRIS/train/other/other (104).png
#   inflating: phishIRIS/train/other/other (46).jpg
#   inflating: phishIRIS/train/other/other (153).jpg
#   inflating: phishIRIS/train/other/other (11).png
#   inflating: phishIRIS/train/other/other (190).png
#   inflating: phishIRIS/train/other/other (85).png
#   inflating: phishIRIS/train/other/other (128).jpg
#   inflating: phishIRIS/train/other/other (128).png
#   inflating: phishIRIS/train/other/other (85).jpg
#   inflating: phishIRIS/train/other/other (201).png
#   inflating: phishIRIS/train/other/other (93).jpg
#   inflating: phishIRIS/train/other/other (186).jpg
#   inflating: phishIRIS/train/other/other (169).jpg
#   inflating: phishIRIS/train/other/other (186).png
#   inflating: phishIRIS/train/other/other (169).png
#   inflating: phishIRIS/train/other/other (93).png
#   inflating: phishIRIS/train/other/other (92).png
#   inflating: phishIRIS/train/other/other (187).png
#   inflating: phishIRIS/train/other/other (168).png
#   inflating: phishIRIS/train/other/other (168).jpg
#   inflating: phishIRIS/train/other/other (92).jpg
#   inflating: phishIRIS/train/other/other (200).png
#   inflating: phishIRIS/train/other/other (129).png
#   inflating: phishIRIS/train/other/other (84).jpg
#   inflating: phishIRIS/train/other/other (84).png
#   inflating: phishIRIS/train/other/other (129).jpg
#   inflating: phishIRIS/train/other/other (191).png
#   inflating: phishIRIS/train/other/other (152).jpg
#   inflating: phishIRIS/train/other/other (10).png
#   inflating: phishIRIS/train/other/other (105).png
#   inflating: phishIRIS/train/other/other (47).jpg
#   inflating: phishIRIS/train/other/other (105).jpg
#   inflating: phishIRIS/train/other/other (47).png
#   inflating: phishIRIS/train/other/other (152).png
#   inflating: phishIRIS/train/other/other (10).jpg
#   inflating: phishIRIS/train/other/other (113).jpg
#   inflating: phishIRIS/train/other/other (51).png
#   inflating: phishIRIS/train/other/other (144).png
#   inflating: phishIRIS/train/other/other (144).jpg
#   inflating: phishIRIS/train/other/other (113).png
#   inflating: phishIRIS/train/other/other (51).jpg
#   inflating: phishIRIS/train/other/other (26).jpg
#   inflating: phishIRIS/train/other/other (164).png
#   inflating: phishIRIS/train/other/other (71).png
#   inflating: phishIRIS/train/other/other (133).jpg
#   inflating: phishIRIS/train/other/other (71).jpg
#   inflating: phishIRIS/train/other/other (133).png
#   inflating: phishIRIS/train/other/other (26).png
#   inflating: phishIRIS/train/other/other (164).jpg
#   inflating: phishIRIS/train/other/other (67).jpg
#   inflating: phishIRIS/train/other/other (88).jpg
#   inflating: phishIRIS/train/other/other (125).png
#   inflating: phishIRIS/train/other/other (30).png
#   inflating: phishIRIS/train/other/other (172).jpg
#   inflating: phishIRIS/train/other/other (30).jpg
#   inflating: phishIRIS/train/other/other (172).png
#   inflating: phishIRIS/train/other/other (67).png
#   inflating: phishIRIS/train/other/other (125).jpg
#   inflating: phishIRIS/train/other/other (88).png
#   inflating: phishIRIS/train/other/other (109).png
#   inflating: phishIRIS/train/other/other (109).jpg
#   inflating: phishIRIS/train/other/other (148).png
#   inflating: phishIRIS/train/other/other (148).jpg
#   inflating: phishIRIS/train/alibaba/alibaba (11).png
#   inflating: phishIRIS/train/alibaba/alibaba (46).png
#   inflating: phishIRIS/train/alibaba/alibaba (31).png
#   inflating: phishIRIS/train/alibaba/alibaba (27).png
#   inflating: phishIRIS/train/alibaba/alibaba (26).png
#   inflating: phishIRIS/train/alibaba/alibaba (30).png
#   inflating: phishIRIS/train/alibaba/alibaba (1).png
#   inflating: phishIRIS/train/alibaba/alibaba (1).jpg
#   inflating: phishIRIS/train/alibaba/alibaba (47).png
#   inflating: phishIRIS/train/alibaba/alibaba (10).png
#   inflating: phishIRIS/train/alibaba/alibaba (37).png
#   inflating: phishIRIS/train/alibaba/alibaba (21).png
#   inflating: phishIRIS/train/alibaba/alibaba (17).png
#   inflating: phishIRIS/train/alibaba/alibaba (40).png
#   inflating: phishIRIS/train/alibaba/alibaba (6).png
#   inflating: phishIRIS/train/alibaba/alibaba (7).png
#   inflating: phishIRIS/train/alibaba/alibaba (41).png
#   inflating: phishIRIS/train/alibaba/alibaba (16).png
#   inflating: phishIRIS/train/alibaba/alibaba (20).png
#   inflating: phishIRIS/train/alibaba/alibaba (36).png
#   inflating: phishIRIS/train/alibaba/alibaba (23).png
#   inflating: phishIRIS/train/alibaba/alibaba (8).png
#   inflating: phishIRIS/train/alibaba/alibaba (35).png
#   inflating: phishIRIS/train/alibaba/alibaba (19).png
#   inflating: phishIRIS/train/alibaba/alibaba (4).png
#   inflating: phishIRIS/train/alibaba/alibaba (39).png
#   inflating: phishIRIS/train/alibaba/alibaba (42).png
#   inflating: phishIRIS/train/alibaba/alibaba (15).png
#   inflating: phishIRIS/train/alibaba/alibaba (14).png
#   inflating: phishIRIS/train/alibaba/alibaba (43).png
#   inflating: phishIRIS/train/alibaba/alibaba (38).png
#   inflating: phishIRIS/train/alibaba/alibaba (5).png
#   inflating: phishIRIS/train/alibaba/alibaba (18).png
#   inflating: phishIRIS/train/alibaba/alibaba (34).png
#   inflating: phishIRIS/train/alibaba/alibaba (22).png
#   inflating: phishIRIS/train/alibaba/alibaba (9).png
#   inflating: phishIRIS/train/alibaba/alibaba (29).png
#   inflating: phishIRIS/train/alibaba/alibaba (2).png
#   inflating: phishIRIS/train/alibaba/alibaba (44).png
#   inflating: phishIRIS/train/alibaba/alibaba (13).png
#   inflating: phishIRIS/train/alibaba/alibaba (25).png
#   inflating: phishIRIS/train/alibaba/alibaba (33).png
#   inflating: phishIRIS/train/alibaba/alibaba (48).png
#   inflating: phishIRIS/train/alibaba/alibaba (49).png
#   inflating: phishIRIS/train/alibaba/alibaba (32).png
#   inflating: phishIRIS/train/alibaba/alibaba (24).png
#   inflating: phishIRIS/train/alibaba/alibaba (12).png
#   inflating: phishIRIS/train/alibaba/alibaba (45).png
#   inflating: phishIRIS/train/alibaba/alibaba (28).png
#   inflating: phishIRIS/train/alibaba/alibaba (3).png
#   inflating: phishIRIS/train/adobe/adobe (34).png
#   inflating: phishIRIS/train/adobe/adobe (22).png
#   inflating: phishIRIS/train/adobe/adobe (8).png
#   inflating: phishIRIS/train/adobe/adobe (18).png
#   inflating: phishIRIS/train/adobe/adobe (38).png
#   inflating: phishIRIS/train/adobe/adobe (4).png
#   inflating: phishIRIS/train/adobe/adobe (43).png
#   inflating: phishIRIS/train/adobe/adobe (14).png
#   inflating: phishIRIS/train/adobe/adobe (15).png
#   inflating: phishIRIS/train/adobe/adobe (42).png
#   inflating: phishIRIS/train/adobe/adobe (5).png
#   inflating: phishIRIS/train/adobe/adobe (39).png
#   inflating: phishIRIS/train/adobe/adobe (19).png
#   inflating: phishIRIS/train/adobe/adobe (9).png
#   inflating: phishIRIS/train/adobe/adobe (23).png
#   inflating: phishIRIS/train/adobe/adobe (35).png
#   inflating: phishIRIS/train/adobe/adobe (28).png
#   inflating: phishIRIS/train/adobe/adobe (2).png
#   inflating: phishIRIS/train/adobe/adobe (12).png
#   inflating: phishIRIS/train/adobe/adobe (32).png
#   inflating: phishIRIS/train/adobe/adobe (24).png
#   inflating: phishIRIS/train/adobe/adobe (25).png
#   inflating: phishIRIS/train/adobe/adobe (33).png
#   inflating: phishIRIS/train/adobe/adobe (13).png
#   inflating: phishIRIS/train/adobe/adobe (3).png
#   inflating: phishIRIS/train/adobe/adobe (29).png
#   inflating: phishIRIS/train/adobe/adobe (10).png
#   inflating: phishIRIS/train/adobe/adobe (26).png
#   inflating: phishIRIS/train/adobe/adobe (30).png
#   inflating: phishIRIS/train/adobe/adobe (31).png
#   inflating: phishIRIS/train/adobe/adobe (27).png
#   inflating: phishIRIS/train/adobe/adobe (1).png
#   inflating: phishIRIS/train/adobe/adobe (11).png
#   inflating: phishIRIS/train/adobe/adobe (20).png
#   inflating: phishIRIS/train/adobe/adobe (36).png
#   inflating: phishIRIS/train/adobe/adobe (16).png
#   inflating: phishIRIS/train/adobe/adobe (41).png
#   inflating: phishIRIS/train/adobe/adobe (6).png
#   inflating: phishIRIS/train/adobe/adobe (7).png
#   inflating: phishIRIS/train/adobe/adobe (40).png
#   inflating: phishIRIS/train/adobe/adobe (17).png
#   inflating: phishIRIS/train/adobe/adobe (37).png
#   inflating: phishIRIS/train/adobe/adobe (21).png
#   inflating: phishIRIS/train/facebook/facebook (85).png
#   inflating: phishIRIS/train/facebook/facebook (11).png
#   inflating: phishIRIS/train/facebook/facebook (46).png
#   inflating: phishIRIS/train/facebook/facebook (50).png
#   inflating: phishIRIS/train/facebook/facebook (70).png
#   inflating: phishIRIS/train/facebook/facebook (1).png
#   inflating: phishIRIS/train/facebook/facebook (27).png
#   inflating: phishIRIS/train/facebook/facebook (1).jpg
#   inflating: phishIRIS/train/facebook/facebook (31).png
#   inflating: phishIRIS/train/facebook/facebook (66).png
#   inflating: phishIRIS/train/facebook/facebook (67).png
#   inflating: phishIRIS/train/facebook/facebook (30).png
#   inflating: phishIRIS/train/facebook/facebook (26).png
#   inflating: phishIRIS/train/facebook/facebook (71).png
#   inflating: phishIRIS/train/facebook/facebook (51).png
#   inflating: phishIRIS/train/facebook/facebook (47).png
#   inflating: phishIRIS/train/facebook/facebook (10).png
#   inflating: phishIRIS/train/facebook/facebook (84).png
#   inflating: phishIRIS/train/facebook/facebook (76).png
#   inflating: phishIRIS/train/facebook/facebook (7).png
#   inflating: phishIRIS/train/facebook/facebook (21).png
#   inflating: phishIRIS/train/facebook/facebook (37).png
#   inflating: phishIRIS/train/facebook/facebook (60).png
#   inflating: phishIRIS/train/facebook/facebook (83).png
#   inflating: phishIRIS/train/facebook/facebook (17).png
#   inflating: phishIRIS/train/facebook/facebook (40).png
#   inflating: phishIRIS/train/facebook/facebook (56).png
#   inflating: phishIRIS/train/facebook/facebook (57).png
#   inflating: phishIRIS/train/facebook/facebook (41).png
#   inflating: phishIRIS/train/facebook/facebook (16).png
#   inflating: phishIRIS/train/facebook/facebook (82).png
#   inflating: phishIRIS/train/facebook/facebook (61).png
#   inflating: phishIRIS/train/facebook/facebook (36).png
#   inflating: phishIRIS/train/facebook/facebook (20).png
#   inflating: phishIRIS/train/facebook/facebook (77).png
#   inflating: phishIRIS/train/facebook/facebook (6).png
#   inflating: phishIRIS/train/facebook/facebook (58).png
#   inflating: phishIRIS/train/facebook/facebook (19).png
#   inflating: phishIRIS/train/facebook/facebook (62).png
#   inflating: phishIRIS/train/facebook/facebook (35).png
#   inflating: phishIRIS/train/facebook/facebook (23).png
#   inflating: phishIRIS/train/facebook/facebook (5).png
#   inflating: phishIRIS/train/facebook/facebook (74).png
#   inflating: phishIRIS/train/facebook/facebook (54).png
#   inflating: phishIRIS/train/facebook/facebook (42).png
#   inflating: phishIRIS/train/facebook/facebook (15).png
#   inflating: phishIRIS/train/facebook/facebook (81).png
#   inflating: phishIRIS/train/facebook/facebook (39).png
#   inflating: phishIRIS/train/facebook/facebook (9).png
#   inflating: phishIRIS/train/facebook/facebook (78).png
#   inflating: phishIRIS/train/facebook/facebook (8).png
#   inflating: phishIRIS/train/facebook/facebook (79).png
#   inflating: phishIRIS/train/facebook/facebook (38).png
#   inflating: phishIRIS/train/facebook/facebook (80).png
#   inflating: phishIRIS/train/facebook/facebook (14).png
#   inflating: phishIRIS/train/facebook/facebook (43).png
#   inflating: phishIRIS/train/facebook/facebook (55).png
#   inflating: phishIRIS/train/facebook/facebook (4).png
#   inflating: phishIRIS/train/facebook/facebook (75).png
#   inflating: phishIRIS/train/facebook/facebook (22).png
#   inflating: phishIRIS/train/facebook/facebook (34).png
#   inflating: phishIRIS/train/facebook/facebook (63).png
#   inflating: phishIRIS/train/facebook/facebook (18).png
#   inflating: phishIRIS/train/facebook/facebook (59).png
#   inflating: phishIRIS/train/facebook/facebook (52).png
#   inflating: phishIRIS/train/facebook/facebook (44).png
#   inflating: phishIRIS/train/facebook/facebook (13).png
#   inflating: phishIRIS/train/facebook/facebook (68).png
#   inflating: phishIRIS/train/facebook/facebook (29).png
#   inflating: phishIRIS/train/facebook/facebook (48).png
#   inflating: phishIRIS/train/facebook/facebook (64).png
#   inflating: phishIRIS/train/facebook/facebook (33).png
#   inflating: phishIRIS/train/facebook/facebook (25).png
#   inflating: phishIRIS/train/facebook/facebook (3).png
#   inflating: phishIRIS/train/facebook/facebook (72).png
#   inflating: phishIRIS/train/facebook/facebook (2).png
#   inflating: phishIRIS/train/facebook/facebook (73).png
#   inflating: phishIRIS/train/facebook/facebook (24).png
#   inflating: phishIRIS/train/facebook/facebook (2).jpg
#   inflating: phishIRIS/train/facebook/facebook (32).png
#   inflating: phishIRIS/train/facebook/facebook (65).png
#   inflating: phishIRIS/train/facebook/facebook (49).png
#   inflating: phishIRIS/train/facebook/facebook (28).png
#   inflating: phishIRIS/train/facebook/facebook (69).png
#   inflating: phishIRIS/train/facebook/facebook (12).png
#   inflating: phishIRIS/train/facebook/facebook (45).png
#   inflating: phishIRIS/train/facebook/facebook (53).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (38).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (43).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (14).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (14).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (1).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (55).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (1).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (22).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (22).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (63).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (34).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (18).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (18).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (59).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (58).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (19).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (19).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (35).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (62).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (23).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (23).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (54).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (15).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (15).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (42).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (39).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (24).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (65).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (32).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (49).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (28).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (45).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (12).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (12).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (7).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (53).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (7).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (6).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (52).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (6).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (13).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (13).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (44).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (29).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (48).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (33).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (64).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (25).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (9).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (9).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (30).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (26).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (5).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (51).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (5).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (10).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (10).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (47).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (46).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (11).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (11).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (4).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (50).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (4).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (27).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (66).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (31).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (8).png
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (8).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (3).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (57).jpg
#   inflating: phishIRIS/train/wellsfargo/wellsfargo (3).png
# ...
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (23).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (1).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (1).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (20).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (20).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (16).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (16).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (17).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (17).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (21).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (21).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (10).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (10).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (7).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (7).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (6).png
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (6).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (11).jpg
#   inflating: phishIRIS/val/wellsfargo/wellsfargo_test (11).png
#   inflating: phishIRIS/val/paypal/paypal_test (10).png
#   inflating: phishIRIS/val/paypal/paypal_test (47).png
#   inflating: phishIRIS/val/paypal/paypal_test (10).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (51).png
#   inflating: phishIRIS/val/paypal/paypal_test (1).png
#   inflating: phishIRIS/val/paypal/paypal_test (1).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (26).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (26).png
#   inflating: phishIRIS/val/paypal/paypal_test (30).png
#   inflating: phishIRIS/val/paypal/paypal_test (67).png
#   inflating: phishIRIS/val/paypal/paypal_test (66).png
#   inflating: phishIRIS/val/paypal/paypal_test (31).png
#   inflating: phishIRIS/val/paypal/paypal_test (27).png
#   inflating: phishIRIS/val/paypal/paypal_test (50).png
#   inflating: phishIRIS/val/paypal/paypal_test (11).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (46).png
#   inflating: phishIRIS/val/paypal/paypal_test (11).png
#   inflating: phishIRIS/val/paypal/paypal_test (7).png
#   inflating: phishIRIS/val/paypal/paypal_test (7).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (20).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (20).png
#   inflating: phishIRIS/val/paypal/paypal_test (36).png
#   inflating: phishIRIS/val/paypal/paypal_test (61).png
#   inflating: phishIRIS/val/paypal/paypal_test (16).png
#   inflating: phishIRIS/val/paypal/paypal_test (41).png
#   inflating: phishIRIS/val/paypal/paypal_test (16).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (57).png
#   inflating: phishIRIS/val/paypal/paypal_test (56).png
#   inflating: phishIRIS/val/paypal/paypal_test (17).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (40).png
#   inflating: phishIRIS/val/paypal/paypal_test (17).png
#   inflating: phishIRIS/val/paypal/paypal_test (60).png
#   inflating: phishIRIS/val/paypal/paypal_test (37).png
#   inflating: phishIRIS/val/paypal/paypal_test (21).png
#   inflating: phishIRIS/val/paypal/paypal_test (21).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (6).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (6).png
#   inflating: phishIRIS/val/paypal/paypal_test (63).png
#   inflating: phishIRIS/val/paypal/paypal_test (34).png
#   inflating: phishIRIS/val/paypal/paypal_test (22).png
#   inflating: phishIRIS/val/paypal/paypal_test (22).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (59).png
#   inflating: phishIRIS/val/paypal/paypal_test (5).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (18).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (5).png
#   inflating: phishIRIS/val/paypal/paypal_test (18).png
#   inflating: phishIRIS/val/paypal/paypal_test (38).png
#   inflating: phishIRIS/val/paypal/paypal_test (55).png
#   inflating: phishIRIS/val/paypal/paypal_test (9).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (14).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (43).png
#   inflating: phishIRIS/val/paypal/paypal_test (9).png
#   inflating: phishIRIS/val/paypal/paypal_test (14).png
#   inflating: phishIRIS/val/paypal/paypal_test (8).png
#   inflating: phishIRIS/val/paypal/paypal_test (15).png
#   inflating: phishIRIS/val/paypal/paypal_test (42).png
#   inflating: phishIRIS/val/paypal/paypal_test (8).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (15).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (54).png
#   inflating: phishIRIS/val/paypal/paypal_test (39).png
#   inflating: phishIRIS/val/paypal/paypal_test (4).png
#   inflating: phishIRIS/val/paypal/paypal_test (19).png
#   inflating: phishIRIS/val/paypal/paypal_test (4).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (19).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (58).png
#   inflating: phishIRIS/val/paypal/paypal_test (23).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (23).png
#   inflating: phishIRIS/val/paypal/paypal_test (35).png
#   inflating: phishIRIS/val/paypal/paypal_test (62).png
#   inflating: phishIRIS/val/paypal/paypal_test (28).png
#   inflating: phishIRIS/val/paypal/paypal_test (53).png
#   inflating: phishIRIS/val/paypal/paypal_test (12).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (45).png
#   inflating: phishIRIS/val/paypal/paypal_test (12).png
#   inflating: phishIRIS/val/paypal/paypal_test (65).png
#   inflating: phishIRIS/val/paypal/paypal_test (32).png
#   inflating: phishIRIS/val/paypal/paypal_test (24).png
#   inflating: phishIRIS/val/paypal/paypal_test (24).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (49).png
#   inflating: phishIRIS/val/paypal/paypal_test (3).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (3).png
#   inflating: phishIRIS/val/paypal/paypal_test (2).png
#   inflating: phishIRIS/val/paypal/paypal_test (2).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (48).png
#   inflating: phishIRIS/val/paypal/paypal_test (25).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (25).png
#   inflating: phishIRIS/val/paypal/paypal_test (33).png
#   inflating: phishIRIS/val/paypal/paypal_test (64).png
#   inflating: phishIRIS/val/paypal/paypal_test (13).png
#   inflating: phishIRIS/val/paypal/paypal_test (44).png
#   inflating: phishIRIS/val/paypal/paypal_test (13).jpg
#   inflating: phishIRIS/val/paypal/paypal_test (52).png
#   inflating: phishIRIS/val/paypal/paypal_test (29).png
#   inflating: phishIRIS/val/boa/boa_test (2).jpeg
#   inflating: phishIRIS/val/boa/boa_test (13).png
#   inflating: phishIRIS/val/boa/boa_test (3).jpg
#   inflating: phishIRIS/val/boa/boa_test (3).png
#   inflating: phishIRIS/val/boa/boa_test (2).png
#   inflating: phishIRIS/val/boa/boa_test (2).jpg
#   inflating: phishIRIS/val/boa/boa_test (12).png
#   inflating: phishIRIS/val/boa/boa_test (1).jpeg
#   inflating: phishIRIS/val/boa/boa_test (5).jpg
#   inflating: phishIRIS/val/boa/boa_test (5).png
#   inflating: phishIRIS/val/boa/boa_test (23).png
#   inflating: phishIRIS/val/boa/boa_test (19).png
#   inflating: phishIRIS/val/boa/boa_test (9).jpg
#   inflating: phishIRIS/val/boa/boa_test (9).png
#   inflating: phishIRIS/val/boa/boa_test (15).png
#   inflating: phishIRIS/val/boa/boa_test (14).png
#   inflating: phishIRIS/val/boa/boa_test (8).png
#   inflating: phishIRIS/val/boa/boa_test (8).jpg
#   inflating: phishIRIS/val/boa/boa_test (18).png
#   inflating: phishIRIS/val/boa/boa_test (4).png
#   inflating: phishIRIS/val/boa/boa_test (22).png
#   inflating: phishIRIS/val/boa/boa_test (4).jpg
#   inflating: phishIRIS/val/boa/boa_test (21).png
#   inflating: phishIRIS/val/boa/boa_test (7).png
#   inflating: phishIRIS/val/boa/boa_test (7).jpg
#   inflating: phishIRIS/val/boa/boa_test (17).png
#   inflating: phishIRIS/val/boa/boa_test (16).png
#   inflating: phishIRIS/val/boa/boa_test (6).jpg
#   inflating: phishIRIS/val/boa/boa_test (20).png
#   inflating: phishIRIS/val/boa/boa_test (6).png
#   inflating: phishIRIS/val/boa/boa_test (11).png
#   inflating: phishIRIS/val/boa/boa_test (1).png
#   inflating: phishIRIS/val/boa/boa_test (1).jpg
#   inflating: phishIRIS/val/boa/boa_test (10).png
#   inflating: phishIRIS/val/boa/boa_test (10).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (12).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (12).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (8).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (28).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (8).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (24).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (4).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (4).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (5).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (25).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (5).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (9).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (9).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (13).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (18).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (2).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (22).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (2).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (14).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (15).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (3).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (3).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (23).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (19).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (20).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (16).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (17).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (21).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (1).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (1).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (10).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (10).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (6).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (6).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (26).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (7).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (27).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (7).png
#   inflating: phishIRIS/val/dropbox/dropbox_test (11).jpg
#   inflating: phishIRIS/val/dropbox/dropbox_test (11).png
#   inflating: phishIRIS/val/dhl/dhl_test (8).png
#   inflating: phishIRIS/val/dhl/dhl_test (8).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (13).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (13).png
#   inflating: phishIRIS/val/dhl/dhl_test (29).png
#   inflating: phishIRIS/val/dhl/dhl_test (4).png
#   inflating: phishIRIS/val/dhl/dhl_test (4).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (25).png
#   inflating: phishIRIS/val/dhl/dhl_test (24).png
#   inflating: phishIRIS/val/dhl/dhl_test (5).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (5).png
#   inflating: phishIRIS/val/dhl/dhl_test (28).png
#   inflating: phishIRIS/val/dhl/dhl_test (12).png
#   inflating: phishIRIS/val/dhl/dhl_test (12).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (9).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (9).png
#   inflating: phishIRIS/val/dhl/dhl_test (2).png
#   inflating: phishIRIS/val/dhl/dhl_test (2).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (19).png
#   inflating: phishIRIS/val/dhl/dhl_test (23).png
#   inflating: phishIRIS/val/dhl/dhl_test (15).png
#   inflating: phishIRIS/val/dhl/dhl_test (14).png
#   inflating: phishIRIS/val/dhl/dhl_test (22).png
#   inflating: phishIRIS/val/dhl/dhl_test (18).png
#   inflating: phishIRIS/val/dhl/dhl_test (3).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (3).png
#   inflating: phishIRIS/val/dhl/dhl_test (21).png
#   inflating: phishIRIS/val/dhl/dhl_test (17).png
#   inflating: phishIRIS/val/dhl/dhl_test (16).png
#   inflating: phishIRIS/val/dhl/dhl_test (1).png
#   inflating: phishIRIS/val/dhl/dhl_test (1).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (20).png
#   inflating: phishIRIS/val/dhl/dhl_test (11).png
#   inflating: phishIRIS/val/dhl/dhl_test (11).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (27).png
#   inflating: phishIRIS/val/dhl/dhl_test (6).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (6).png
#   inflating: phishIRIS/val/dhl/dhl_test (7).png
#   inflating: phishIRIS/val/dhl/dhl_test (7).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (26).png
#   inflating: phishIRIS/val/dhl/dhl_test (10).jpg
#   inflating: phishIRIS/val/dhl/dhl_test (10).png
#   inflating: phishIRIS/val/linkedin/linkedin_test (1).png
#   inflating: phishIRIS/val/linkedin/linkedin_test (1).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (7).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (6).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (5).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (5).png
#   inflating: phishIRIS/val/linkedin/linkedin_test (9).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (8).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (4).png
#   inflating: phishIRIS/val/linkedin/linkedin_test (4).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (3).jpg
#   inflating: phishIRIS/val/linkedin/linkedin_test (3).png
#   inflating: phishIRIS/val/linkedin/linkedin_test (2).png
#   inflating: phishIRIS/val/linkedin/linkedin_test (2).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (16).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (16).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (7).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (20).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (7).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (6).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (21).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (6).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (17).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (17).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (1).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (26).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (1).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (10).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (10).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (11).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (11).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (27).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (3).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (24).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (3).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (12).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (12).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (13).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (13).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (2).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (25).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (2).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (9).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (9).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (14).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (14).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (5).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (22).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (5).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (18).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (19).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (4).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (23).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (4).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (15).jpg
#   inflating: phishIRIS/val/yahoo/yahoo_test (15).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (8).png
#   inflating: phishIRIS/val/yahoo/yahoo_test (8).jpg

# %%
# !ls -l
# Out:
# total 12
# drwx------ 5 root root 4096 Jan 24 01:28 gdrive
# drwxr-xr-x 5 root root 4096 Dec 19 15:32 phishIRIS
# drwxr-xr-x 1 root root 4096 Jan 20 17:27 sample_data

# %%
from __future__ import print_function, division
from builtins import range, input
# Note: you may need to update your version of future
# sudo pip install -U future

from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model, Sequential
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

import tensorflow as tf
from keras.optimizers import Adam

from sklearn.metrics import confusion_matrix
import numpy as np
import matplotlib.pyplot as plt

import glob
import os

# %%
# re-size all the images to this
height=256
width=256
        

# training config:
epochs = 50
batch_size = 32

# %%
list_of_architectures = [
    "DenseNet121",
    "DenseNet169",
    "DenseNet201"
    
]

# %%
data_dir="phishIRIS/"
train_path = data_dir + 'train'
valid_path = data_dir + 'val'

# %%
# useful for getting number of files
image_files = glob.glob(train_path + '/*/*.*')
valid_image_files = glob.glob(valid_path + '/*/*.*')

# useful for getting number of classes
folders = glob.glob(train_path + '/*')

# %%
# look at an image for fun
plt.imshow(image.load_img(np.random.choice(image_files)))
plt.show()

# %%
def createImageAugmentation(preprocess_input, IMAGE_SIZE):
    # create an instance of ImageDataGenerator
    gen = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.1,
      zoom_range=0.2,
      horizontal_flip=True,
      vertical_flip=True,
      preprocessing_function=preprocess_input
    )
    
    test_gen = gen.flow_from_directory(valid_path, target_size=IMAGE_SIZE)
    print(test_gen.class_indices)
    labels = [None] * len(test_gen.class_indices)
    for k, v in test_gen.class_indices.items():
      labels[v] = k
    
    # create generators
    train_generator = gen.flow_from_directory(
      train_path,
      target_size=IMAGE_SIZE,
      shuffle=True,
      batch_size=batch_size,
    )
    valid_generator = gen.flow_from_directory(
      valid_path,
      target_size=IMAGE_SIZE,
      shuffle=True,
      batch_size=batch_size,
    )
    
    return train_generator, valid_generator, gen, labels

# %% [markdown]
# # test generator to see how it works and some other useful things
#
# # get label mapping for confusion matrix plot later
# test_gen = gen.flow_from_directory(valid_path, target_size=IMAGE_SIZE)
# print(test_gen.class_indices)
# labels = [None] * len(test_gen.class_indices)
# for k, v in test_gen.class_indices.items():
#   labels[v] = k

# %% [markdown]
# # should be a strangely colored image (due to VGG weights being BGR)
# for x, y in test_gen:
#   print("min:", x[0].min(), "max:", x[0].max())
#   plt.title(labels[np.argmax(y[0])])
#   plt.imshow(x[0])
#   plt.show()
#   break

# %% [markdown]
# # create generators
# train_generator = gen.flow_from_directory(
#   train_path,
#   target_size=IMAGE_SIZE,
#   shuffle=True,
#   batch_size=batch_size,
# )
# valid_generator = gen.flow_from_directory(
#   valid_path,
#   target_size=IMAGE_SIZE,
#   shuffle=True,
#   batch_size=batch_size,
# )

# %%
def get_confusion_matrix(data_path, N, gen, model, IMAGE_SIZE):
  # we need to see the data in the same order
  # for both predictions and targets
  print("Generating confusion matrix", N)
  predictions = []
  targets = []
  i = 0
  for x, y in gen.flow_from_directory(data_path, target_size=IMAGE_SIZE, shuffle=False, batch_size=batch_size * 2):
    i += 1
    if i % 50 == 0:
      print(i)
    p = model.predict(x)
    p = np.argmax(p, axis=1)
    y = np.argmax(y, axis=1)
    predictions = np.concatenate((predictions, p))
    targets = np.concatenate((targets, y))
    if len(targets) >= N:
      break

  cm = confusion_matrix(targets, predictions)
  return cm

# %%
from __future__ import print_function, division
from builtins import range, input
# Note: you may need to update your version of future
# sudo pip install -U future

import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  #print(cm)
  figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")
  #plt.figure(figsize=(10,10))
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()

# %%
def classify(model_name):
    
    if model_name == "Xception":
        from keras.applications.xception import Xception, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = Xception(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
    
    elif model_name == "VGG16":
        from keras.applications.vgg16 import VGG16, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = VGG16(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        x = Dense(4096, activation='relu')(x)
        x = Dense(4096, activation='relu')(x)
        
    
    elif model_name == "VGG19":
        from keras.applications.vgg19 import VGG19, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = VGG19(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        x = Dense(4096, activation='relu')(x)
        x = Dense(4096, activation='relu')(x)
        
    elif model_name == "ResNet50V2":
        from keras.applications.resnet_v2 import ResNet50V2, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = ResNet50V2(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "ResNet101V2":
        from keras.applications.resnet_v2 import ResNet101V2, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = ResNet101V2(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "ResNet152V2":
        from keras.applications.resnet_v2 import ResNet152V2, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = ResNet152V2(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "InceptionV3":
        from keras.applications.inception_v3 import InceptionV3, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = InceptionV3(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)

    elif model_name == "MobileNet":
        from keras.applications.mobilenet import MobileNet, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = MobileNet(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "MobileNetV2":
        from keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = MobileNetV2(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "DenseNet121":
        from keras.applications.densenet import DenseNet121, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = DenseNet121(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "DenseNet169":
        from keras.applications.densenet import DenseNet169, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = DenseNet169(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
        
    elif model_name == "DenseNet201":
        from keras.applications.densenet import DenseNet201, preprocess_input
        IMAGE_SIZE = [height, width]
        train_generator, valid_generator, gen, labels = createImageAugmentation(preprocess_input, IMAGE_SIZE)
        base_model = DenseNet201(input_shape=(height, width,3), weights='imagenet', include_top=False)
        for layers in base_model.layers:
            layers.trainable=False
        x = Flatten()(base_model.output)
    
    prediction = Dense(15, activation='softmax')(x)
    model = Model(inputs=base_model.input, outputs=prediction)
        
    

    print(model.summary())
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

    r = model.fit_generator(
      train_generator,
      validation_data=valid_generator,
      epochs=epochs,
      steps_per_epoch=len(image_files) // batch_size,
      validation_steps=len(valid_image_files) // batch_size,
    )

    cm = get_confusion_matrix(train_path, len(image_files), gen, model, IMAGE_SIZE)
    valid_cm = get_confusion_matrix(valid_path, len(valid_image_files), gen, model, IMAGE_SIZE)

    # loss
    plt.plot(r.history['loss'], label='train loss')
    plt.plot(r.history['val_loss'], label='val loss')
    plt.legend()
    plt.show()

    # accuracies
    plt.plot(r.history['accuracy'], label='train acc')
    plt.plot(r.history['val_accuracy'], label='val acc')
    plt.legend()
    plt.show()

    #from util import plot_confusion_matrix
    plot_confusion_matrix(cm, labels, title='Train confusion matrix')
    plot_confusion_matrix(valid_cm, labels, title='Validation confusion matrix')

# %%
for model_name in list_of_architectures:
    print(model_name)
    classify(model_name)
# Out:
# DenseNet121
# Found 1539 images belonging to 15 classes.
# {'adobe': 0, 'alibaba': 1, 'amazon': 2, 'apple': 3, 'boa': 4, 'chase': 5, 'dhl': 6, 'dropbox': 7, 'facebook': 8, 'linkedin': 9, 'microsoft': 10, 'other': 11, 'paypal': 12, 'wellsfargo': 13, 'yahoo': 14}
# Found 1313 images belonging to 15 classes.
# Found 1539 images belonging to 15 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1/conv (Conv2D)             (None, 128, 128, 64) 9408        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1/bn (BatchNormalization)   (None, 128, 128, 64) 256         conv1/conv[0][0]
# __________________________________________________________________________________________________
# conv1/relu (Activation)         (None, 128, 128, 64) 0           conv1/bn[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 130, 130, 64) 0           conv1/relu[0][0]
# __________________________________________________________________________________________________
# pool1 (MaxPooling2D)            (None, 64, 64, 64)   0           zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 64, 64, 64)   256         pool1[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_relu (Activation (None, 64, 64, 64)   0           conv2_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 64, 64, 128)  8192        conv2_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 64, 64, 128)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_concat (Concatenat (None, 64, 64, 96)   0           pool1[0][0]
#                                                                  conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_bn (BatchNormali (None, 64, 64, 96)   384         conv2_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block2_0_relu (Activation (None, 64, 64, 96)   0           conv2_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 64, 64, 128)  12288       conv2_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 64, 64, 128)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_concat (Concatenat (None, 64, 64, 128)  0           conv2_block1_concat[0][0]
#                                                                  conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block3_0_relu (Activation (None, 64, 64, 128)  0           conv2_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 64, 64, 128)  16384       conv2_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 64, 64, 128)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_concat (Concatenat (None, 64, 64, 160)  0           conv2_block2_concat[0][0]
#                                                                  conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_bn (BatchNormali (None, 64, 64, 160)  640         conv2_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block4_0_relu (Activation (None, 64, 64, 160)  0           conv2_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_conv (Conv2D)    (None, 64, 64, 128)  20480       conv2_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block4_1_relu (Activation (None, 64, 64, 128)  0           conv2_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block4_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block4_concat (Concatenat (None, 64, 64, 192)  0           conv2_block3_concat[0][0]
#                                                                  conv2_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_bn (BatchNormali (None, 64, 64, 192)  768         conv2_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block5_0_relu (Activation (None, 64, 64, 192)  0           conv2_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_conv (Conv2D)    (None, 64, 64, 128)  24576       conv2_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block5_1_relu (Activation (None, 64, 64, 128)  0           conv2_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block5_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block5_concat (Concatenat (None, 64, 64, 224)  0           conv2_block4_concat[0][0]
#                                                                  conv2_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_bn (BatchNormali (None, 64, 64, 224)  896         conv2_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv2_block6_0_relu (Activation (None, 64, 64, 224)  0           conv2_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_conv (Conv2D)    (None, 64, 64, 128)  28672       conv2_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_bn (BatchNormali (None, 64, 64, 128)  512         conv2_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block6_1_relu (Activation (None, 64, 64, 128)  0           conv2_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block6_2_conv (Conv2D)    (None, 64, 64, 32)   36864       conv2_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block6_concat (Concatenat (None, 64, 64, 256)  0           conv2_block5_concat[0][0]
#                                                                  conv2_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# pool2_bn (BatchNormalization)   (None, 64, 64, 256)  1024        conv2_block6_concat[0][0]
# __________________________________________________________________________________________________
# pool2_relu (Activation)         (None, 64, 64, 256)  0           pool2_bn[0][0]
# __________________________________________________________________________________________________
# pool2_conv (Conv2D)             (None, 64, 64, 128)  32768       pool2_relu[0][0]
# __________________________________________________________________________________________________
# pool2_pool (AveragePooling2D)   (None, 32, 32, 128)  0           pool2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 32, 32, 128)  512         pool2_pool[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_relu (Activation (None, 32, 32, 128)  0           conv3_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 32, 32, 128)  16384       conv3_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 32, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_concat (Concatenat (None, 32, 32, 160)  0           pool2_pool[0][0]
#                                                                  conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_bn (BatchNormali (None, 32, 32, 160)  640         conv3_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block2_0_relu (Activation (None, 32, 32, 160)  0           conv3_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 32, 32, 128)  20480       conv3_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 32, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_concat (Concatenat (None, 32, 32, 192)  0           conv3_block1_concat[0][0]
#                                                                  conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_bn (BatchNormali (None, 32, 32, 192)  768         conv3_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block3_0_relu (Activation (None, 32, 32, 192)  0           conv3_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 32, 32, 128)  24576       conv3_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 32, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_concat (Concatenat (None, 32, 32, 224)  0           conv3_block2_concat[0][0]
#                                                                  conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_bn (BatchNormali (None, 32, 32, 224)  896         conv3_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block4_0_relu (Activation (None, 32, 32, 224)  0           conv3_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 32, 32, 128)  28672       conv3_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 32, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_concat (Concatenat (None, 32, 32, 256)  0           conv3_block3_concat[0][0]
#                                                                  conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_bn (BatchNormali (None, 32, 32, 256)  1024        conv3_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block5_0_relu (Activation (None, 32, 32, 256)  0           conv3_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_conv (Conv2D)    (None, 32, 32, 128)  32768       conv3_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block5_1_relu (Activation (None, 32, 32, 128)  0           conv3_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block5_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block5_concat (Concatenat (None, 32, 32, 288)  0           conv3_block4_concat[0][0]
#                                                                  conv3_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_bn (BatchNormali (None, 32, 32, 288)  1152        conv3_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block6_0_relu (Activation (None, 32, 32, 288)  0           conv3_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_conv (Conv2D)    (None, 32, 32, 128)  36864       conv3_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block6_1_relu (Activation (None, 32, 32, 128)  0           conv3_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block6_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block6_concat (Concatenat (None, 32, 32, 320)  0           conv3_block5_concat[0][0]
#                                                                  conv3_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_bn (BatchNormali (None, 32, 32, 320)  1280        conv3_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block7_0_relu (Activation (None, 32, 32, 320)  0           conv3_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_conv (Conv2D)    (None, 32, 32, 128)  40960       conv3_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block7_1_relu (Activation (None, 32, 32, 128)  0           conv3_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block7_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block7_concat (Concatenat (None, 32, 32, 352)  0           conv3_block6_concat[0][0]
#                                                                  conv3_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_bn (BatchNormali (None, 32, 32, 352)  1408        conv3_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block8_0_relu (Activation (None, 32, 32, 352)  0           conv3_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_conv (Conv2D)    (None, 32, 32, 128)  45056       conv3_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block8_1_relu (Activation (None, 32, 32, 128)  0           conv3_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block8_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block8_concat (Concatenat (None, 32, 32, 384)  0           conv3_block7_concat[0][0]
#                                                                  conv3_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_bn (BatchNormali (None, 32, 32, 384)  1536        conv3_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block9_0_relu (Activation (None, 32, 32, 384)  0           conv3_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_conv (Conv2D)    (None, 32, 32, 128)  49152       conv3_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_bn (BatchNormali (None, 32, 32, 128)  512         conv3_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block9_1_relu (Activation (None, 32, 32, 128)  0           conv3_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block9_2_conv (Conv2D)    (None, 32, 32, 32)   36864       conv3_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block9_concat (Concatenat (None, 32, 32, 416)  0           conv3_block8_concat[0][0]
#                                                                  conv3_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_bn (BatchNormal (None, 32, 32, 416)  1664        conv3_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block10_0_relu (Activatio (None, 32, 32, 416)  0           conv3_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_conv (Conv2D)   (None, 32, 32, 128)  53248       conv3_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_bn (BatchNormal (None, 32, 32, 128)  512         conv3_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block10_1_relu (Activatio (None, 32, 32, 128)  0           conv3_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block10_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv3_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block10_concat (Concatena (None, 32, 32, 448)  0           conv3_block9_concat[0][0]
#                                                                  conv3_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_bn (BatchNormal (None, 32, 32, 448)  1792        conv3_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block11_0_relu (Activatio (None, 32, 32, 448)  0           conv3_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_conv (Conv2D)   (None, 32, 32, 128)  57344       conv3_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_bn (BatchNormal (None, 32, 32, 128)  512         conv3_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block11_1_relu (Activatio (None, 32, 32, 128)  0           conv3_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block11_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv3_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block11_concat (Concatena (None, 32, 32, 480)  0           conv3_block10_concat[0][0]
#                                                                  conv3_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_bn (BatchNormal (None, 32, 32, 480)  1920        conv3_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv3_block12_0_relu (Activatio (None, 32, 32, 480)  0           conv3_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_conv (Conv2D)   (None, 32, 32, 128)  61440       conv3_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_bn (BatchNormal (None, 32, 32, 128)  512         conv3_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block12_1_relu (Activatio (None, 32, 32, 128)  0           conv3_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block12_2_conv (Conv2D)   (None, 32, 32, 32)   36864       conv3_block12_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block12_concat (Concatena (None, 32, 32, 512)  0           conv3_block11_concat[0][0]
#                                                                  conv3_block12_2_conv[0][0]
# __________________________________________________________________________________________________
# pool3_bn (BatchNormalization)   (None, 32, 32, 512)  2048        conv3_block12_concat[0][0]
# __________________________________________________________________________________________________
# pool3_relu (Activation)         (None, 32, 32, 512)  0           pool3_bn[0][0]
# __________________________________________________________________________________________________
# pool3_conv (Conv2D)             (None, 32, 32, 256)  131072      pool3_relu[0][0]
# __________________________________________________________________________________________________
# pool3_pool (AveragePooling2D)   (None, 16, 16, 256)  0           pool3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 16, 16, 256)  1024        pool3_pool[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_relu (Activation (None, 16, 16, 256)  0           conv4_block1_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 16, 16, 128)  32768       conv4_block1_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 16, 16, 128)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_concat (Concatenat (None, 16, 16, 288)  0           pool3_pool[0][0]
#                                                                  conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_bn (BatchNormali (None, 16, 16, 288)  1152        conv4_block1_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block2_0_relu (Activation (None, 16, 16, 288)  0           conv4_block2_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 16, 16, 128)  36864       conv4_block2_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 16, 16, 128)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_concat (Concatenat (None, 16, 16, 320)  0           conv4_block1_concat[0][0]
#                                                                  conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_bn (BatchNormali (None, 16, 16, 320)  1280        conv4_block2_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block3_0_relu (Activation (None, 16, 16, 320)  0           conv4_block3_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 16, 16, 128)  40960       conv4_block3_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 16, 16, 128)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_concat (Concatenat (None, 16, 16, 352)  0           conv4_block2_concat[0][0]
#                                                                  conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_bn (BatchNormali (None, 16, 16, 352)  1408        conv4_block3_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block4_0_relu (Activation (None, 16, 16, 352)  0           conv4_block4_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 16, 16, 128)  45056       conv4_block4_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 16, 16, 128)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_concat (Concatenat (None, 16, 16, 384)  0           conv4_block3_concat[0][0]
#                                                                  conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_bn (BatchNormali (None, 16, 16, 384)  1536        conv4_block4_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block5_0_relu (Activation (None, 16, 16, 384)  0           conv4_block5_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 16, 16, 128)  49152       conv4_block5_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 16, 16, 128)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_concat (Concatenat (None, 16, 16, 416)  0           conv4_block4_concat[0][0]
#                                                                  conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_bn (BatchNormali (None, 16, 16, 416)  1664        conv4_block5_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block6_0_relu (Activation (None, 16, 16, 416)  0           conv4_block6_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 16, 16, 128)  53248       conv4_block6_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 16, 16, 128)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_concat (Concatenat (None, 16, 16, 448)  0           conv4_block5_concat[0][0]
#                                                                  conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_bn (BatchNormali (None, 16, 16, 448)  1792        conv4_block6_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block7_0_relu (Activation (None, 16, 16, 448)  0           conv4_block7_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_conv (Conv2D)    (None, 16, 16, 128)  57344       conv4_block7_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block7_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block7_1_relu (Activation (None, 16, 16, 128)  0           conv4_block7_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block7_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block7_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block7_concat (Concatenat (None, 16, 16, 480)  0           conv4_block6_concat[0][0]
#                                                                  conv4_block7_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_bn (BatchNormali (None, 16, 16, 480)  1920        conv4_block7_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block8_0_relu (Activation (None, 16, 16, 480)  0           conv4_block8_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_conv (Conv2D)    (None, 16, 16, 128)  61440       conv4_block8_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block8_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block8_1_relu (Activation (None, 16, 16, 128)  0           conv4_block8_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block8_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block8_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block8_concat (Concatenat (None, 16, 16, 512)  0           conv4_block7_concat[0][0]
#                                                                  conv4_block8_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_bn (BatchNormali (None, 16, 16, 512)  2048        conv4_block8_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block9_0_relu (Activation (None, 16, 16, 512)  0           conv4_block9_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_conv (Conv2D)    (None, 16, 16, 128)  65536       conv4_block9_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_bn (BatchNormali (None, 16, 16, 128)  512         conv4_block9_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block9_1_relu (Activation (None, 16, 16, 128)  0           conv4_block9_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block9_2_conv (Conv2D)    (None, 16, 16, 32)   36864       conv4_block9_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block9_concat (Concatenat (None, 16, 16, 544)  0           conv4_block8_concat[0][0]
#                                                                  conv4_block9_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_bn (BatchNormal (None, 16, 16, 544)  2176        conv4_block9_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block10_0_relu (Activatio (None, 16, 16, 544)  0           conv4_block10_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_conv (Conv2D)   (None, 16, 16, 128)  69632       conv4_block10_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_bn (BatchNormal (None, 16, 16, 128)  512         conv4_block10_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block10_1_relu (Activatio (None, 16, 16, 128)  0           conv4_block10_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block10_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv4_block10_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block10_concat (Concatena (None, 16, 16, 576)  0           conv4_block9_concat[0][0]
#                                                                  conv4_block10_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_bn (BatchNormal (None, 16, 16, 576)  2304        conv4_block10_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block11_0_relu (Activatio (None, 16, 16, 576)  0           conv4_block11_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_conv (Conv2D)   (None, 16, 16, 128)  73728       conv4_block11_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_bn (BatchNormal (None, 16, 16, 128)  512         conv4_block11_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block11_1_relu (Activatio (None, 16, 16, 128)  0           conv4_block11_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block11_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv4_block11_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block11_concat (Concatena (None, 16, 16, 608)  0           conv4_block10_concat[0][0]
#                                                                  conv4_block11_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_bn (BatchNormal (None, 16, 16, 608)  2432        conv4_block11_concat[0][0]
# __________________________________________________________________________________________________
# conv4_block12_0_relu (Activatio (None, 16, 16, 608)  0           conv4_block12_0_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_conv (Conv2D)   (None, 16, 16, 128)  77824       conv4_block12_0_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_bn (BatchNormal (None, 16, 16, 128)  512         conv4_block12_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block12_1_relu (Activatio (None, 16, 16, 128)  0           conv4_block12_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block12_2_conv (Conv2D)   (None, 16, 16, 32)   36864       conv4_block12_1_relu[0][0]
# ...
#                                                                  conv5_block30_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_bn (BatchNormal (None, 8, 8, 1856)   7424        conv5_block30_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block31_0_relu (Activatio (None, 8, 8, 1856)   0           conv5_block31_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_conv (Conv2D)   (None, 8, 8, 128)    237568      conv5_block31_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block31_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block31_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block31_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block31_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block31_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block31_concat (Concatena (None, 8, 8, 1888)   0           conv5_block30_concat[0][0]
#                                                                  conv5_block31_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_bn (BatchNormal (None, 8, 8, 1888)   7552        conv5_block31_concat[0][0]
# __________________________________________________________________________________________________
# conv5_block32_0_relu (Activatio (None, 8, 8, 1888)   0           conv5_block32_0_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_conv (Conv2D)   (None, 8, 8, 128)    241664      conv5_block32_0_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_bn (BatchNormal (None, 8, 8, 128)    512         conv5_block32_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block32_1_relu (Activatio (None, 8, 8, 128)    0           conv5_block32_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block32_2_conv (Conv2D)   (None, 8, 8, 32)     36864       conv5_block32_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block32_concat (Concatena (None, 8, 8, 1920)   0           conv5_block31_concat[0][0]
#                                                                  conv5_block32_2_conv[0][0]
# __________________________________________________________________________________________________
# bn (BatchNormalization)         (None, 8, 8, 1920)   7680        conv5_block32_concat[0][0]
# __________________________________________________________________________________________________
# relu (Activation)               (None, 8, 8, 1920)   0           bn[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 122880)       0           relu[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 15)           1843215     flatten_2[0][0]
# ==================================================================================================
# Total params: 20,165,199
# Trainable params: 1,843,215
# Non-trainable params: 18,321,984
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 41/41 [==============================] - 92s 2s/step - loss: 2.6798 - accuracy: 0.2812 - precision_2: 0.4239 - recall_2: 0.1792 - val_loss: 1.0461 - val_accuracy: 0.6784 - val_precision_2: 0.8322 - val_recall_2: 0.5586
# Epoch 2/50
# 41/41 [==============================] - 79s 2s/step - loss: 1.1967 - accuracy: 0.6282 - precision_2: 0.7686 - recall_2: 0.4770 - val_loss: 0.7473 - val_accuracy: 0.7760 - val_precision_2: 0.8656 - val_recall_2: 0.6960
# Epoch 3/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.9000 - accuracy: 0.7207 - precision_2: 0.8231 - recall_2: 0.6189 - val_loss: 0.6876 - val_accuracy: 0.7858 - val_precision_2: 0.8670 - val_recall_2: 0.7090
# Epoch 4/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.5775 - accuracy: 0.8016 - precision_2: 0.8863 - recall_2: 0.7394 - val_loss: 0.6820 - val_accuracy: 0.7923 - val_precision_2: 0.8771 - val_recall_2: 0.7344
# Epoch 5/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.5514 - accuracy: 0.8272 - precision_2: 0.8910 - recall_2: 0.7522 - val_loss: 0.5483 - val_accuracy: 0.8385 - val_precision_2: 0.8988 - val_recall_2: 0.7865
# Epoch 6/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.4326 - accuracy: 0.8596 - precision_2: 0.9010 - recall_2: 0.7916 - val_loss: 0.7291 - val_accuracy: 0.7702 - val_precision_2: 0.8471 - val_recall_2: 0.7070
# Epoch 7/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.4423 - accuracy: 0.8586 - precision_2: 0.9032 - recall_2: 0.7995 - val_loss: 0.6099 - val_accuracy: 0.8138 - val_precision_2: 0.8721 - val_recall_2: 0.7721
# Epoch 8/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.3441 - accuracy: 0.8997 - precision_2: 0.9405 - recall_2: 0.8537 - val_loss: 0.5180 - val_accuracy: 0.8568 - val_precision_2: 0.8928 - val_recall_2: 0.8353
# Epoch 9/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.2739 - accuracy: 0.9169 - precision_2: 0.9569 - recall_2: 0.8753 - val_loss: 0.5285 - val_accuracy: 0.8464 - val_precision_2: 0.8882 - val_recall_2: 0.8118
# Epoch 10/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.2426 - accuracy: 0.9307 - precision_2: 0.9632 - recall_2: 0.9021 - val_loss: 0.5142 - val_accuracy: 0.8542 - val_precision_2: 0.8824 - val_recall_2: 0.8158
# Epoch 11/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.2338 - accuracy: 0.9349 - precision_2: 0.9608 - recall_2: 0.9089 - val_loss: 0.4804 - val_accuracy: 0.8509 - val_precision_2: 0.8961 - val_recall_2: 0.8197
# Epoch 12/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1854 - accuracy: 0.9536 - precision_2: 0.9727 - recall_2: 0.9217 - val_loss: 0.5266 - val_accuracy: 0.8509 - val_precision_2: 0.8822 - val_recall_2: 0.8190
# Epoch 13/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1994 - accuracy: 0.9403 - precision_2: 0.9562 - recall_2: 0.9178 - val_loss: 0.4599 - val_accuracy: 0.8613 - val_precision_2: 0.8940 - val_recall_2: 0.8405
# Epoch 14/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1867 - accuracy: 0.9423 - precision_2: 0.9644 - recall_2: 0.9155 - val_loss: 0.4562 - val_accuracy: 0.8620 - val_precision_2: 0.8960 - val_recall_2: 0.8470
# Epoch 15/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.2192 - accuracy: 0.9348 - precision_2: 0.9516 - recall_2: 0.8970 - val_loss: 0.4555 - val_accuracy: 0.8750 - val_precision_2: 0.9015 - val_recall_2: 0.8464
# Epoch 16/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1369 - accuracy: 0.9636 - precision_2: 0.9789 - recall_2: 0.9474 - val_loss: 0.4676 - val_accuracy: 0.8711 - val_precision_2: 0.8965 - val_recall_2: 0.8516
# Epoch 17/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1623 - accuracy: 0.9550 - precision_2: 0.9624 - recall_2: 0.9369 - val_loss: 0.4767 - val_accuracy: 0.8678 - val_precision_2: 0.8974 - val_recall_2: 0.8431
# Epoch 18/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1213 - accuracy: 0.9658 - precision_2: 0.9842 - recall_2: 0.9483 - val_loss: 0.4869 - val_accuracy: 0.8496 - val_precision_2: 0.8786 - val_recall_2: 0.8340
# Epoch 19/50
# 41/41 [==============================] - 80s 2s/step - loss: 0.1275 - accuracy: 0.9614 - precision_2: 0.9757 - recall_2: 0.9446 - val_loss: 0.5528 - val_accuracy: 0.8542 - val_precision_2: 0.8864 - val_recall_2: 0.8385
# Epoch 20/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1155 - accuracy: 0.9658 - precision_2: 0.9758 - recall_2: 0.9564 - val_loss: 0.5343 - val_accuracy: 0.8424 - val_precision_2: 0.8786 - val_recall_2: 0.8249
# Epoch 21/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1011 - accuracy: 0.9752 - precision_2: 0.9798 - recall_2: 0.9651 - val_loss: 0.5553 - val_accuracy: 0.8359 - val_precision_2: 0.8662 - val_recall_2: 0.8177
# Epoch 22/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1140 - accuracy: 0.9588 - precision_2: 0.9668 - recall_2: 0.9535 - val_loss: 0.6234 - val_accuracy: 0.8216 - val_precision_2: 0.8473 - val_recall_2: 0.8053
# Epoch 23/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0932 - accuracy: 0.9851 - precision_2: 0.9884 - recall_2: 0.9738 - val_loss: 0.4680 - val_accuracy: 0.8776 - val_precision_2: 0.8969 - val_recall_2: 0.8665
# Epoch 24/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1239 - accuracy: 0.9559 - precision_2: 0.9636 - recall_2: 0.9437 - val_loss: 0.5123 - val_accuracy: 0.8594 - val_precision_2: 0.8837 - val_recall_2: 0.8457
# Epoch 25/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.2623 - accuracy: 0.9285 - precision_2: 0.9431 - recall_2: 0.9124 - val_loss: 0.6033 - val_accuracy: 0.8249 - val_precision_2: 0.8538 - val_recall_2: 0.8099
# Epoch 26/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1173 - accuracy: 0.9687 - precision_2: 0.9739 - recall_2: 0.9588 - val_loss: 0.5323 - val_accuracy: 0.8600 - val_precision_2: 0.8865 - val_recall_2: 0.8438
# Epoch 27/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0774 - accuracy: 0.9847 - precision_2: 0.9858 - recall_2: 0.9739 - val_loss: 0.6676 - val_accuracy: 0.8177 - val_precision_2: 0.8441 - val_recall_2: 0.7897
# Epoch 28/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1204 - accuracy: 0.9558 - precision_2: 0.9664 - recall_2: 0.9480 - val_loss: 0.7048 - val_accuracy: 0.7982 - val_precision_2: 0.8356 - val_recall_2: 0.7741
# Epoch 29/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1505 - accuracy: 0.9548 - precision_2: 0.9657 - recall_2: 0.9434 - val_loss: 0.5526 - val_accuracy: 0.8483 - val_precision_2: 0.8744 - val_recall_2: 0.8340
# Epoch 30/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0884 - accuracy: 0.9792 - precision_2: 0.9866 - recall_2: 0.9705 - val_loss: 0.4926 - val_accuracy: 0.8698 - val_precision_2: 0.8849 - val_recall_2: 0.8613
# Epoch 31/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0851 - accuracy: 0.9772 - precision_2: 0.9819 - recall_2: 0.9663 - val_loss: 0.5406 - val_accuracy: 0.8613 - val_precision_2: 0.8804 - val_recall_2: 0.8529
# Epoch 32/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0698 - accuracy: 0.9780 - precision_2: 0.9808 - recall_2: 0.9715 - val_loss: 0.4670 - val_accuracy: 0.8828 - val_precision_2: 0.8941 - val_recall_2: 0.8743
# Epoch 33/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0749 - accuracy: 0.9811 - precision_2: 0.9863 - recall_2: 0.9733 - val_loss: 0.4460 - val_accuracy: 0.8880 - val_precision_2: 0.9007 - val_recall_2: 0.8796
# Epoch 34/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0922 - accuracy: 0.9740 - precision_2: 0.9773 - recall_2: 0.9655 - val_loss: 0.4424 - val_accuracy: 0.8880 - val_precision_2: 0.9057 - val_recall_2: 0.8757
# Epoch 35/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0700 - accuracy: 0.9847 - precision_2: 0.9887 - recall_2: 0.9777 - val_loss: 0.6918 - val_accuracy: 0.8073 - val_precision_2: 0.8386 - val_recall_2: 0.7845
# Epoch 36/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0925 - accuracy: 0.9760 - precision_2: 0.9830 - recall_2: 0.9673 - val_loss: 0.5866 - val_accuracy: 0.8496 - val_precision_2: 0.8689 - val_recall_2: 0.8327
# Epoch 37/50
# 41/41 [==============================] - 80s 2s/step - loss: 0.0676 - accuracy: 0.9869 - precision_2: 0.9899 - recall_2: 0.9819 - val_loss: 0.5132 - val_accuracy: 0.8659 - val_precision_2: 0.8840 - val_recall_2: 0.8587
# Epoch 38/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0726 - accuracy: 0.9754 - precision_2: 0.9800 - recall_2: 0.9706 - val_loss: 0.8197 - val_accuracy: 0.7715 - val_precision_2: 0.7986 - val_recall_2: 0.7591
# Epoch 39/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0729 - accuracy: 0.9794 - precision_2: 0.9850 - recall_2: 0.9741 - val_loss: 0.5593 - val_accuracy: 0.8398 - val_precision_2: 0.8741 - val_recall_2: 0.8314
# Epoch 40/50
# 41/41 [==============================] - 80s 2s/step - loss: 0.0659 - accuracy: 0.9792 - precision_2: 0.9848 - recall_2: 0.9772 - val_loss: 0.7252 - val_accuracy: 0.8079 - val_precision_2: 0.8290 - val_recall_2: 0.7891
# Epoch 41/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0638 - accuracy: 0.9850 - precision_2: 0.9872 - recall_2: 0.9832 - val_loss: 0.5667 - val_accuracy: 0.8548 - val_precision_2: 0.8720 - val_recall_2: 0.8470
# Epoch 42/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0740 - accuracy: 0.9778 - precision_2: 0.9832 - recall_2: 0.9744 - val_loss: 0.4841 - val_accuracy: 0.8646 - val_precision_2: 0.8824 - val_recall_2: 0.8548
# Epoch 43/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0737 - accuracy: 0.9814 - precision_2: 0.9883 - recall_2: 0.9772 - val_loss: 0.4676 - val_accuracy: 0.8796 - val_precision_2: 0.8911 - val_recall_2: 0.8737
# Epoch 44/50
# 41/41 [==============================] - 80s 2s/step - loss: 0.0824 - accuracy: 0.9768 - precision_2: 0.9837 - recall_2: 0.9702 - val_loss: 0.5369 - val_accuracy: 0.8620 - val_precision_2: 0.8814 - val_recall_2: 0.8516
# Epoch 45/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.1047 - accuracy: 0.9795 - precision_2: 0.9819 - recall_2: 0.9764 - val_loss: 0.7259 - val_accuracy: 0.8424 - val_precision_2: 0.8564 - val_recall_2: 0.8307
# Epoch 46/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0851 - accuracy: 0.9707 - precision_2: 0.9736 - recall_2: 0.9679 - val_loss: 0.5723 - val_accuracy: 0.8711 - val_precision_2: 0.8894 - val_recall_2: 0.8587
# Epoch 47/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0609 - accuracy: 0.9812 - precision_2: 0.9869 - recall_2: 0.9743 - val_loss: 0.6732 - val_accuracy: 0.8327 - val_precision_2: 0.8533 - val_recall_2: 0.8216
# Epoch 48/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0537 - accuracy: 0.9841 - precision_2: 0.9861 - recall_2: 0.9797 - val_loss: 0.5315 - val_accuracy: 0.8711 - val_precision_2: 0.8893 - val_recall_2: 0.8626
# Epoch 49/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0908 - accuracy: 0.9643 - precision_2: 0.9696 - recall_2: 0.9639 - val_loss: 0.6605 - val_accuracy: 0.8281 - val_precision_2: 0.8488 - val_recall_2: 0.8151
# Epoch 50/50
# 41/41 [==============================] - 79s 2s/step - loss: 0.0637 - accuracy: 0.9768 - precision_2: 0.9831 - recall_2: 0.9768 - val_loss: 0.7118 - val_accuracy: 0.8385 - val_precision_2: 0.8560 - val_recall_2: 0.8281
# Generating confusion matrix 1313
# Found 1313 images belonging to 15 classes.
# Generating confusion matrix 1539
# Found 1539 images belonging to 15 classes.
# Confusion matrix, without normalization
# Confusion matrix, without normalization
